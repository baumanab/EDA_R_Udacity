# %%
import pandas as pd
import numpy as np

# %%
#read in the dataframe
df = pd.read_excel('indicator_hours per week.xlsx')
df.head()
# Out:
#   Working hours per week       1980       1981       1982       1983  \
# 0              Argentina        NaN        NaN        NaN        NaN
# 1              Australia  34.578846  34.578846  34.376923  34.117307
# 2                Austria        NaN        NaN        NaN        NaN
# 3             Bangladesh        NaN        NaN        NaN        NaN
# 4                Belgium        NaN        NaN        NaN  34.000000
#
#         1984       1985       1986       1987       1988    ...      \
# 0        NaN        NaN        NaN        NaN        NaN    ...
# 1  34.415384  34.338461  34.482692  34.655769  34.819230    ...
# 2        NaN        NaN        NaN        NaN        NaN    ...
# 3        NaN        NaN        NaN        NaN        NaN    ...
# 4  34.480769  34.596154  34.211538  33.903846  33.653846    ...
#
#         1998       1999       2000       2001       2002       2003  \
# 0        NaN  35.000000        NaN        NaN        NaN        NaN
# ...

# %%
#rename the first column
columns = list(df.columns)
columns[0] = 'country'
df.columns = columns
df.head()
# Out:
#       country       1980       1981       1982       1983       1984  \
# 0   Argentina        NaN        NaN        NaN        NaN        NaN
# 1   Australia  34.578846  34.578846  34.376923  34.117307  34.415384
# 2     Austria        NaN        NaN        NaN        NaN        NaN
# 3  Bangladesh        NaN        NaN        NaN        NaN        NaN
# 4     Belgium        NaN        NaN        NaN  34.000000  34.480769
#
#         1985       1986       1987       1988    ...           1998  \
# 0        NaN        NaN        NaN        NaN    ...            NaN
# 1  34.338461  34.482692  34.655769  34.819230    ...      34.394231
# 2        NaN        NaN        NaN        NaN    ...      31.990385
# 3        NaN        NaN        NaN        NaN    ...            NaN
# 4  34.596154  34.211538  33.903846  33.653846    ...      32.153846
#
#         1999       2000       2001       2002       2003       2004  \
# 0  35.000000        NaN        NaN        NaN        NaN        NaN
# ...

# %%
#setting index to country
dfreindex = df.set_index(['country'])
dfreindex.head()
# Out:
#                  1980       1981       1982       1983       1984       1985  \
# country
# Argentina         NaN        NaN        NaN        NaN        NaN        NaN
# Australia   34.578846  34.578846  34.376923  34.117307  34.415384  34.338461
# Austria           NaN        NaN        NaN        NaN        NaN        NaN
# Bangladesh        NaN        NaN        NaN        NaN        NaN        NaN
# Belgium           NaN        NaN        NaN  34.000000  34.480769  34.596154
#
#                  1986       1987       1988       1989    ...           1998  \
# country                                                   ...
# Argentina         NaN        NaN        NaN        NaN    ...            NaN
# Australia   34.482692  34.655769  34.819230  34.709616    ...      34.394231
# Austria           NaN        NaN        NaN        NaN    ...      31.990385
# Bangladesh        NaN        NaN        NaN        NaN    ...            NaN
# ...

# %%
#transposing the data frame to do a fillna by mean of country (because doing row by row is complex and ineffcient)
transposed = dfreindex.transpose()
transposed.head()
# Out:
# country  Argentina  Australia  Austria  Bangladesh    Belgium  Brazil  \
# 1980           NaN  34.578846      NaN         NaN        NaN     NaN
# 1981           NaN  34.578846      NaN         NaN        NaN     NaN
# 1982           NaN  34.376923      NaN         NaN        NaN     NaN
# 1983           NaN  34.117307      NaN         NaN  34.000000     NaN
# 1984           NaN  34.415384      NaN         NaN  34.480769     NaN
#
# country     Canada  Chile  Colombia  Costa Rica     ...          Spain  \
# 1980     34.849999    NaN       NaN         NaN     ...      36.776924
# 1981     34.580768    NaN       NaN         NaN     ...      36.121155
# 1982     34.180770    NaN       NaN         NaN     ...      35.717309
# 1983     34.000000    NaN       NaN         NaN     ...      35.103847
# 1984     34.107692    NaN       NaN         NaN     ...      34.242307
#
# country  Sri Lanka     Sweden  Switzerland  Thailand  Turkey  United Kingdom  \
# ...

# %%
#now fill with the mean
filled = transposed.fillna(transposed.mean())
filled.head()
# Out:
# country  Argentina  Australia    Austria  Bangladesh    Belgium     Brazil  \
# 1980          37.5  34.578846  31.696731       44.25  32.012308  33.615385
# 1981          37.5  34.578846  31.696731       44.25  32.012308  33.615385
# 1982          37.5  34.376923  31.696731       44.25  32.012308  33.615385
# 1983          37.5  34.117307  31.696731       44.25  34.000000  33.615385
# 1984          37.5  34.415384  31.696731       44.25  34.480769  33.615385
#
# country     Canada      Chile   Colombia  Costa Rica     ...          Spain  \
# 1980     34.849999  37.128205  37.480769   35.878205     ...      36.776924
# 1981     34.580768  37.128205  37.480769   35.878205     ...      36.121155
# 1982     34.180770  37.128205  37.480769   35.878205     ...      35.717309
# 1983     34.000000  37.128205  37.480769   35.878205     ...      35.103847
# 1984     34.107692  37.128205  37.480769   35.878205     ...      34.242307
#
# ...

# %%
#transpose it back
clean = filled.transpose()
clean.head()
# Out:
#                  1980       1981       1982       1983       1984       1985  \
# country
# Argentina   37.500000  37.500000  37.500000  37.500000  37.500000  37.500000
# Australia   34.578846  34.578846  34.376923  34.117307  34.415384  34.338461
# Austria     31.696731  31.696731  31.696731  31.696731  31.696731  31.696731
# Bangladesh  44.250000  44.250000  44.250000  44.250000  44.250000  44.250000
# Belgium     32.012308  32.012308  32.012308  34.000000  34.480769  34.596154
#
#                  1986       1987       1988       1989    ...           1998  \
# country                                                   ...
# Argentina   37.500000  37.500000  37.500000  37.500000    ...      37.500000
# Australia   34.482692  34.655769  34.819230  34.709616    ...      34.394231
# Austria     31.696731  31.696731  31.696731  31.696731    ...      31.990385
# Bangladesh  44.250000  44.250000  44.250000  44.250000    ...      44.250000
# ...

# %%
#now reset the index back to the old index
clean_reset = clean.reset_index()
clean_reset.head()
# Out:
#       country       1980       1981       1982       1983       1984  \
# 0   Argentina  37.500000  37.500000  37.500000  37.500000  37.500000
# 1   Australia  34.578846  34.578846  34.376923  34.117307  34.415384
# 2     Austria  31.696731  31.696731  31.696731  31.696731  31.696731
# 3  Bangladesh  44.250000  44.250000  44.250000  44.250000  44.250000
# 4     Belgium  32.012308  32.012308  32.012308  34.000000  34.480769
#
#         1985       1986       1987       1988    ...           1998  \
# 0  37.500000  37.500000  37.500000  37.500000    ...      37.500000
# 1  34.338461  34.482692  34.655769  34.819230    ...      34.394231
# 2  31.696731  31.696731  31.696731  31.696731    ...      31.990385
# 3  44.250000  44.250000  44.250000  44.250000    ...      44.250000
# 4  34.596154  34.211538  33.903846  33.653846    ...      32.153846
#
#         1999       2000       2001       2002       2003       2004  \
# 0  35.000000  37.500000  37.500000  37.500000  37.500000  37.500000
# ...

# %%
#switch from wide to long using melt
melt = pd.melt(clean_reset, id_vars= ['country'], var_name= 'year')
melt.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-13b6970c555c> in <module>()
#       1 #switch from wide to long using melt
# ----> 2 melt = pd.melt(clean, id_vars= ['country'], var_name= 'year')
#       3 melt.head()
#
# c:\Users\Andrew\Anaconda\lib\site-packages\pandas\core\reshape.pyc in melt(frame, id_vars, value_vars, var_name, value_name, col_level)
#     760     mdata = {}
#     761     for col in id_vars:
# --> 762         mdata[col] = np.tile(frame.pop(col).values, K)
#     763
#     764     mcolumns = id_vars + var_name + [value_name]
#
# c:\Users\Andrew\Anaconda\lib\site-packages\pandas\core\generic.pyc in pop(self, item)
#     473         Return item and drop from frame. Raise KeyError if not found.
#     474         """
# --> 475         result = self[item]
#     476         del self[item]
#     477         return result
#
# ...

# %%
melt.to_csv('workinghours.csv')
